# %%
#symbols = {"NVDA","META","BYND","CHGG","AAPL","BRK-B","JNJ","AMZN","GOOGL","TSLA","AMD","PLTR","RIVN","COIN","AI","UPST","FSLY","OPEN","HOOD","SPY","QQQ","XLF","XLE","ARKK"} # diverse data
symbols = {"NVDA"}

import functions
from PIL import Image
from IPython.display import display
import random
from datetime import datetime
# loop through symbols, use predictTest, use frequencies as seconds, use 1mo,3mo,6mo,1y,2y,5y as range

def distribute(l:list):
    x = len(l)
    r = [random.random() for _ in range(x)]
    m = [l[i] + r[i] for i in range(x)]
    s = sum(m)
    m = [v / s for v in m]
    return m

weight = [0.005,0.01,0.485,0.49,0.01] #"duration":[weight,freq] - freq in seconds
weights = []
for symbol in symbols:
    realistic = False
    while not realistic:
        #tests:list = distribute(weight)
        tests = weight
        print(tests)
        bias = {90:[tests[0], "ME"], 180:[tests[1], "ME"], 365:[tests[2], "D"], 730:[tests[3], "W"], 1825:[tests[4], "YS"]}
        # instantiate Charts and call projectTest on the instance
        charts_inst = functions.Charts()
        chart_buf = charts_inst.projectTestGraphic(ticker=symbol, weights=str(bias), today=datetime(year=2025, month=4, day=20))
        # projectTest returns an in-memory PNG buffer; open with PIL and display
        img = Image.open(chart_buf)
        display(img)
        realistic = bool(input("Realistic? ")) # Anything: True, Nothing = False
    weight = tests
    weights.append(tests)
