# %%
import psycopg2 as pg
import os
from dotenv import load_dotenv

load_dotenv()

con = pg.connect(dbname="QuantumBot",user=os.getenv("PG_USERNAME"),password=os.getenv("PG_PASSWORD"),host="localhost")
if not con: raise Exception("Connection cannot create")

# %%
cursor = con.cursor()
cursor.execute(f"select * from account where discord = '{1}'")
row = cursor.fetchone()
if row: print(row[0])
# Out:
# 1

# %%
from datetime import datetime

datetime.now().date().month
datetime.now().date().year
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 datetime.now().date().month
#       4 datetime.now().date().year
# ----> 5 datetime.date(12,4,2026)
#
# TypeError: descriptor 'date' for 'datetime.datetime' objects doesn't apply to a 'int' object
