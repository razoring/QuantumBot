# %%
import psycopg2 as pg
import os
from dotenv import load_dotenv

load_dotenv()

con = pg.connect(dbname="QuantumBot",user=os.getenv("PG_USERNAME"),password=os.getenv("PG_PASSWORD"),host="localhost")
if not con: raise Exception("Connection cannot create")

# %%
cursor = con.cursor()
cursor.execute(f"select * from account where discord = '{1}'")
row = cursor.fetchone()
if row: print(row[0])
# Out:
# 1

# %%
from datetime import datetime

datetime.now().strftime("%b %d")
# Out:
# 'Feb 08'

# %%
import yfinance

m = yfinance.Ticker("META")
h = m.history(interval="1d", period="1mo")["Close"]
print(h)
# Out:
# Date
# 2026-01-07 00:00:00-05:00    648.690002
# 2026-01-08 00:00:00-05:00    646.059998
# 2026-01-09 00:00:00-05:00    653.059998
# 2026-01-12 00:00:00-05:00    641.969971
# 2026-01-13 00:00:00-05:00    631.090027
# 2026-01-14 00:00:00-05:00    615.520020
# 2026-01-15 00:00:00-05:00    620.799988
# 2026-01-16 00:00:00-05:00    620.250000
# 2026-01-20 00:00:00-05:00    604.119995
# 2026-01-21 00:00:00-05:00    612.960022
# 2026-01-22 00:00:00-05:00    647.630005
# 2026-01-23 00:00:00-05:00    658.760010
# 2026-01-26 00:00:00-05:00    672.359985
# 2026-01-27 00:00:00-05:00    672.969971
# 2026-01-28 00:00:00-05:00    668.729980
# 2026-01-29 00:00:00-05:00    738.309998
# 2026-01-30 00:00:00-05:00    716.500000
# 2026-02-02 00:00:00-05:00    706.409973
# 2026-02-03 00:00:00-05:00    691.700012
# 2026-02-04 00:00:00-05:00    668.989990
# 2026-02-05 00:00:00-05:00    670.210022
# 2026-02-06 00:00:00-05:00    661.460022
# Name: Close, dtype: float64
